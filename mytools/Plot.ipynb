# %%
import sys
sys.path.insert(0, "/workspace/liukaiyuan")
from mytools import *
import numpy as np
import matplotlib.pyplot as plt

# %%
l = 2009
p = np.load("/workspace/liukaiyuan/MS-TCN/PaddleVideo_Ms-tcn/output/gtea/save_npy/{}_p.npy".format(l))
g = np.load("/workspace/liukaiyuan/MS-TCN/PaddleVideo_Ms-tcn/output/gtea/save_npy/{}_g.npy".format(l))

# %%
plt.figure(figsize=(40,3))
PlotPred(p, num_class=11, line_width=20, scale=100)
PlotPred(g, num_class=11, line_height=1, line_width=20, scale=100)
plt.plot()
# Out:
# []
